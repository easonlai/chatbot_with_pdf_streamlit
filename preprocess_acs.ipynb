# %%
# Import necessary libraries
# pip install azure-search-documents==11.4.0b6
import openai
from langchain.document_loaders import DirectoryLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores.azuresearch import AzureSearch
from azure.core.credentials import AzureKeyCredential

# %%
# Configure the baseline configuration of the OpenAI library for Azure OpenAI Service & Azure Cognitive Search.
OPENAI_API_KEY = "PLEASE_ENTER_YOUR_OWNED_AOAI_SERVICE_KEY"
OPENAI_API_BASE = "https://PLESAE_ENTER_YOUR_OWNED_AOAI_RESOURCE_NAME.openai.azure.com/"
OPENAI_EMBEDDING_DEPLOYMENT_NAME = "PLEASE_ENTER_YOUR_OWNED_AOAI_EMBEDDING_MODEL_NAME"
OPENAI_EMBEDDING_MODEL_NAME = "text-embedding-ada-002"
OPENAI_API_VERSION = "2023-05-15"
OPENAI_API_TYPE = "azure"
openai.api_key = OPENAI_API_KEY
openai.api_base = OPENAI_API_BASE
openai.api_version = OPENAI_API_VERSION
openai.api_type = OPENAI_API_TYPE
AZURE_COGNITIVE_SEARCH_ENDPOINT_NAME = "https://PLESAE_ENTER_YOUR_OWNED_ACS_RESOURCE_NAME.search.windows.net"
AZURE_COGNITIVE_SEARCH_INDEX_NAME = "PLEASE_ENTER_YOUR_OWNED_ACS_INDEX_NAME"
AZURE_COGNITIVE_SEARCH_KEY = "PLEASE_ENTER_YOUR_OWNED_ACS_SERVICE_KEY"
acs_credential = AzureKeyCredential(AZURE_COGNITIVE_SEARCH_KEY)

# %%
# Create directory loader object to load the data from the directory.
pdfLoader = DirectoryLoader('./data/')

# %%
# Initial the document loader to load the data from the directory.
documents = []
documents.extend(pdfLoader.load())

# %%
# Display the number of documents in the directory.
print (f'You have {len(documents)} document(s) in your data folder.')
# Out:
# You have 1 document(s) in your data folder.

# %%
# Split the documents into chunks of 1000 characters with 200 characters overlap.
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
documents = text_splitter.split_documents(documents)
print(len(documents))
# Out:
# Created a chunk of size 1164, which is longer than the specified 1000
# 203

# %%
# Define the function to interact with Azure OpenAI Embedding Model.
embeddings = OpenAIEmbeddings(deployment=OPENAI_EMBEDDING_DEPLOYMENT_NAME, 
                                openai_api_key=OPENAI_API_KEY, 
                                model=OPENAI_EMBEDDING_MODEL_NAME, 
                                openai_api_type=OPENAI_API_TYPE, 
                                chunk_size=1)

# %%
# Define the function interact with Azure Cognitive Search. If the index does not exist, it will be created.
vector_store: AzureSearch = AzureSearch(
    azure_search_endpoint=AZURE_COGNITIVE_SEARCH_ENDPOINT_NAME,
    azure_search_key=AZURE_COGNITIVE_SEARCH_KEY,
    index_name=AZURE_COGNITIVE_SEARCH_INDEX_NAME,
    embedding_function=embeddings.embed_query,
)

# %%
# Upload the embeddings to the vector store.
vector_store.add_documents(documents=documents)
# Out:
# ['ZGUzZjEyMDItMzNiMy00ZDYyLWJmYjEtYjNhMmI4OTdhMjA0',
#  'MjFjMDM1NDMtYTViMy00ZGQ3LWFjMjAtMDk1NDZiOGI1MTIx',
#  'ODVhYWM4ZjAtZjg2Yi00MjM2LTg2ODAtNjM2MWUzNDNlMTlh',
#  'ZWMyNGExZWQtNTg5Ni00NTU3LWE3NmEtNzhiZDQ5YzRkMzZl',
#  'YzIxYjFhZDctYjcwNi00NjM1LTk0NDEtZjg2MjQ0ZGE2M2Ez',
#  'NDdmMTdlYzktYjA2MC00MjNmLTljMTUtYjRmNTc3ODI4Yzhj',
#  'MTkyM2ViOWEtOWMzMC00MzU4LTljNGMtYjZjNjNlNjllYjUw',
#  'OTI3NWQ0MTktNjQ5YS00ZDNmLTlmYzMtZWRjODNmYzYzMzky',
#  'MzBjMDM2NGUtNDM3Yi00ZGFiLWIzZTctMzFmMTg3Y2Y4YTM3',
#  'M2RjNjgzNDctOGJjOC00YTkwLThmNWYtNzkwZGMwMTQ0MmYx',
#  'ZTA5OTc5OGItYjRhMi00MjZmLWIwNDMtMjA2NDU5ZGZlOTI1',
#  'NTc5MjhjMTUtM2EyYy00Y2EyLWE3MTctYTc4NDRmNmZlZTU5',
#  'ZTEzYWQ0YjMtNTdkNC00YTQ5LWFiZWUtNmVjYzc2OTg3NmY4',
#  'ODU1OTIyMDQtNGU0Mi00NTM0LTllYTQtNDQwMmJjOTFhNGE5',
#  'NjcwYjhhYjctMmFmOS00ZWQ2LWEyNTctYzVkYzRhYTUwZTVm',
#  'NmVjZmE0NjYtZmIxOS00ODBhLWJiYTYtZDU5MmIzNWU3MmEx',
#  'YzQ4NjM4NWEtYTkzZC00YWJlLTk4MjItZmJiNThhYzQ4ZmQz',
#  'ZmFjYWY5NTMtYWMwMy00ZDE3LTk1NGEtYWViMmY0ZDA2ZmRj',
#  'MWEyYzg5MmYtNzMzYy00ZGNmLWI4YTctNmFjM2Y1ODg4ZGIy',
#  'MzIxZTQzN2UtYzM5NC00NzljLWJjZmEtNDMwY2U4MjA1MzRl',
#  'OTIwNDk5YTUtNzU4OS00YjgzLWE2MmMtN2EzZGM2Y2M5YzNl',
#  'MjllOGM0MGYtNDdiZS00NzlhLWI4ODAtNzI2ZDVjZWYyMzNl',
#  'Njk1ZWU3M2MtMGMxNC00ZTYxLWI5OWItZGZiNGY5NzBlMWRh',
#  'ODFhNjY3MmYtNDViZi00ZDM1LWE4YjUtMmFkY2E3ZmM4MDY3',
#  'YTBjMzNjMjUtZDQ5Ny00M2I1LThlYzItMmZlOGRhODRjYzEz',
#  'NTgzOWMyMzYtMTE4ZC00ZjIzLTliYzUtZWFiOTk3ZjJmNzcy',
#  'M2U1OTMzNmMtYzczNy00YmE5LTlkMGMtNWY3YzUxNjgzODA5',
#  'Yzc1OGQwMGUtZjYwMC00YTMzLTk2ODItODM3MjAxNjE5ODdh',
#  'YzBhZGViZWQtMzYzMi00NjcwLWEzMTEtMzFmMjczNjgxNmI2',
#  'Y2Y5MGU4MDktZjFhNS00YjUyLWE1YzQtMThlZWQ5ZWQ5ZjUz',
#  'YWY1Y2E1YjQtNDEwOS00YjA3LTlkMDgtYzcwYzVhZTFhOTA0',
#  'MTEwM2EwZDctOGI2MS00MzBmLWE3ZjItNjUzNzEwNWJhY2E2',
#  'OWJiNWQxODEtZGI0MC00YjVjLWE0ZTUtNjkwMGY5MzE4Nzdm',
#  'MDk4NjJlODYtMzUyNC00YzE4LWEwZGEtNjA5ZTViY2Y1YTQ5',
#  'NzRhN2QyZWYtMmQ4ZC00MTBlLWE0OGUtNjE0NTMyZWZhOWU2',
#  'OGRhMWIyZDUtN2IwNy00NmIxLTk4NTAtMWE3ZmU3YjA4OTAz',
#  'M2I5M2FjMGQtYTk3Ny00M2NiLTkxNzEtOTVjZjU5YjgxM2I3',
#  'YjM5YzJjNGYtYzIyNS00MjFjLTllYmYtNTgyYjA2OThlNjMx',
#  'M2UwZjkwM2YtODRjYy00OTE4LWE0MGYtOGRhYzQ4YzI1Y2E5',
#  'Mzk2ODgyZTAtMTlmNi00MTM3LTkxYTItYjRkMTZhNGU3MzZl',
#  'NGE0Y2ZkOTUtNjIyYy00YmUyLWI2N2ItZDZkMjQxNmEzYjVi',
#  'YzE1MDllOGUtZGQwNC00NTFkLWFlZjYtYWVlMTcyMjg4ZWNi',
#  'OTAzZjlhZWYtMjI4My00ZTY4LTlkMzAtMTZkZGY5YjIyN2I3',
#  'NDc0NGVhZmYtYzdlZi00MTlmLWIzMGMtNGMxNTVkYzA4YTI5',
#  'NGU4MzIxZGUtODkzNi00YmQ4LWFhZTktZmQxNjAyYTRmNWI4',
#  'YWMxNzdhMmQtN2E0Mi00ZTQzLWJiYjctYjA3YWNlOGI1NjQ4',
#  'MjgzNGIzMDUtYzkwNy00MGY3LWEyNWYtODg0NmUxYWVkYWNi',
#  'NjJmZTU5Y2EtODdlOC00ZWExLTgxMjAtMTZmY2I0NDM0ODdi',
#  'ZTdhNmNjMTYtYmI3Zi00ZGMyLWE1NTItNzA3NzUzZDdjNGM2',
#  'ZTg2NDkxZGQtZjcxOC00M2ViLWE1YTMtNmQ3YTA0ZTY3Y2Fh',
#  'OGZlMDZhYTgtYWUwNy00MzJlLTkzMTgtMWYzYjc3MjdiZGY5',
#  'MjFkZTdiYTYtY2Q4Zi00NzFhLTkzY2EtMGRiMmRjMGJhNWVh',
#  'Njk3ZWI5Y2UtMWZiMi00M2E4LWJiZGUtZjdmYzBjNDdiNTRh',
#  'MzUzMWQxODAtNDhlOC00ZDY3LWJkODAtNjAzODM1ODdmZjdh',
#  'NWM2NzJkZWYtOWMwYi00YzdkLWI1YjUtMGEzZjA4ZDI2NDhi',
#  'ZTkwZGQ0ZWEtNWE2OS00Nzk3LTllMzQtNTFmODc1MjVkNjM0',
#  'YzkxMDQ1MjMtOWIyYy00NmZkLTliZjctZmY0YTJjZTQ3ODMw',
#  'Y2I1MWJmNTItYTcyOC00N2UyLTk1YWEtMjMyYmVjYWE5ODBh',
#  'NGU4ODI1MDctZjM0YS00MGQ4LWE4OTQtNjkxOTZhZjdhYzcx',
#  'Mjk3YTY5NGYtMzgxOS00NGM0LTk1MTctNWRhMTBlNTZkN2Ux',
#  'Yzg5OGRhOWEtYzA2NS00NGRjLTg0N2QtY2I3ZTcyZDAxMjFh',
#  'MmJhZjczMjctNzUzNS00OWU4LWE5NzEtOWRhMjcxZmEwYjBk',
#  'NzdmNTNmOGUtZGM5NS00ZWZlLWE0MWYtNjFmM2VmM2Y5N2Nj',
#  'MjgzYmI0YTgtMzMyMS00ZTg3LWJlZTEtMzA5YTM5Nzc5NmEz',
#  'MGViMzM3ZjEtMjFkNy00ZDZiLThjYzUtNDNhOWI5MzlmZGJj',
#  'ZTc2YzE4MTMtY2QyMi00OTA2LThlNGUtMGFiNjRhMDY2MjIx',
#  'ZGUwOTMxMWQtM2NiNy00MGNjLWJjMWQtN2U0NDFkZjQxNTk3',
#  'NTI0OGZhNWMtNzk5Ni00MzMzLTgzMzUtNjU2YTlhMWRjNWMz',
#  'NTU1ZjBkM2EtYzZmOC00MzliLWE4NTUtYzQ0MzgxZGU1MWU2',
#  'NDE0Y2M4NGItMmE0ZS00YmU5LWFjNTItNzFkZWMyZTM4MjRi',
#  'ZDZiYjExNDMtZDExYS00YjFjLWJhNjUtN2YyMzlhYjU1Njk3',
#  'ZmUyNWY3ZWUtMzhkZS00NWJkLTlhMmUtMzFkZmEwMDQzOWUy',
#  'ZGYwNjVkZmQtMDQ0YS00NTI0LWFlYTQtN2ViNmFjODM0NDUx',
#  'NTg5NzlhYWItOTg5ZC00MjM0LWIzMTktNTRhM2YzOTBiM2Qz',
#  'NDA2MjIxNTgtYzNhNS00M2RkLWI5MDctOTdkZWY1OTViYzdk',
#  'MzEzODRhMjEtOWMwMi00NGUyLWFjNDAtYzE3ZGY4MmY1N2Mx',
#  'OThmMDJkY2EtZjQ4Yy00ZjhmLTljNjktMzBmYWI5NTkwODNl',
#  'OTA1N2Y0ZjctZWU2Mi00ZWE3LTg2ZGYtYTEwMWY5MmIzYzhi',
#  'MzRlOGVlNjUtMzk4Yi00NWNmLWIxOTUtNDUzMGEyZTZlZWU5',
#  'YmFhOWFhNzgtN2FmOS00ZTNjLThjNzMtZjI5MTk0ZDliZjRi',
#  'OGYwZGIwZDItODY1Yi00ODNiLTgzNjQtOWJkMTFkYWY5M2Fh',
#  'YmE1MjgxNTQtMTZlNi00OGQ3LWJmNDQtYjBmYzViNGVlOGU4',
#  'NmZlM2U5ZjgtNzZhYy00MjdkLWJmOTgtN2E0ZjcxOGZlMDYy',
#  'NmY4OTMzNTctOWY3ZC00YjI3LWIwZDYtZWJmOWE4ODEwYmRl',
#  'ZjI1NjIyYTgtM2MyNy00YmMwLWIxMDUtOTEzOGE1MWY5MGQ2',
#  'ZTQ4MDY1MzMtM2M0Yi00MjQwLWI3MzUtZmM4MDE0MGIxMTY3',
#  'ODIyOTM4NzAtNWI2Ni00MDNmLWJiMTUtNjk5ZTI5NDYzN2Ri',
#  'N2QxNjhhZWItNTk4Mi00MGEyLTkzMGUtYTY4ZjdjZDhhNGVl',
#  'NGNmMzIwMDktODhiZC00NjIxLThkYmYtYzE4MzE0MzAwZDBm']
